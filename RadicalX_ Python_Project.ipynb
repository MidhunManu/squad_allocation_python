# %% [markdown]
# ## Squad Matching Algorithm

# %% [markdown]
# #### Import all required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Load Dataset

# %%
df = pd.read_csv("SquadData.csv",header=None)

# %%
df.head(5)
# Out:
#         0          1                                                  2   \
# 0     Name  Squad_Num                                      Prefered_Lang
# 1  Grayson        NaN  i prefer english but i am also able to communi...
# 2    Jonas        NaN                                            English
# 3    Ronan        NaN               English and Spanish are good for me.
# 4    Dulce        NaN                                            spanish
#
#                                                  3    4   \
# 0                                    Interested_Grp  Age
# 1                 Product Marketing,Product Growth    23
# 2  Product Marketing,Product Growth ,Product Design   23
# 3                                    Product Design   34
# 4                                    Product Design   38
#
#                         5          6         7              8   \
# 0                     City    Country    Region       Timezone
# 1       bordj bou arreridj    Algeria      MENA  Europe,Africa
# 2                  Algiers    Algeria      MENA  Africa,Europe
# 3  Buenos Aires, Argentina  Argentina  Americas       Americas
# 4                  Mendoza  Argentina  Americas       Americas
#
#                                   9   ...              17  \
# 0                         Occupation  ...  Product_Design
# 1  Recently Graduated and Unemployed  ...             NaN
# 2  Recently Graduated and Unemployed  ...               3
# 3                           Employed  ...               4
# 4                           Employed  ...               3
#
#                      18                19              20  \
# 0  Prodcut_Developement  Growth_Marketing  Leading_Groups
# 1                   NaN                 4             NaN
# 2                   NaN                 4               4
# 3                   NaN               NaN               5
# 4                   NaN               NaN               4
#
#                            21  \
# 0             Internship_News
# 1                    linkedin
# 2                    Linkedin
# 3  A friend told me about it.
# 4                    Linkedin
#
#                                                   22  \
# 0                           Cohort_Product_Marketing
# 1    Starting on 15th August,Starting on 22nd August
# 2  Starting on 12th September,Starting on 15th Au...
# 3                                                NaN
# 4                                                NaN
#
#                                                 23  \
# 0                            Cohort_Product_Design
# 1                                              NaN
# 2  Starting on 3rd October,Starting on 22nd August
# 3                          Starting on 22nd August
# 4                          Starting on 22nd August
#
#                            24                         25              26
# 0  Cohort_Product_Development      Cohort_Product_Growth  Hours_Per_Week
# 1                         NaN  Starting on 5th September     20-25 hours
# 2                         NaN    Starting on 3rd October     10-15 hours
# 3                         NaN                        NaN     15-20 hours
# 4                         NaN                        NaN     20-25 hours
#
# [5 rows x 27 columns]

# %%
headers = ["Name","Squad_Num","Prefered_Lang","Interested_Grp","Age","City","Country","Region","Timezone",
          "Occupation","Degree","Prev_Took_Courses","Intern_Experience","Product_Management","Digital_Marketing",
          "Market_Research","Digital_Illustration","Product_Design","Prodcut_Developement","Growth_Marketing",
          "Leading_Groups","Internship_News","Cohort_Product_Marketing","Cohort_Product_Design",
          "Cohort_Product_Development","Cohort_Product_Growth","Hours_Per_Week"]

# %%
df = df.drop(index=0)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.columns = headers

# %%
abc_str = ['English','Hindi','Espanyol']

# %%
df.head(10)
# Out:
#       Name Squad_Num                                      Prefered_Lang  \
# 0  Grayson       NaN  i prefer english but i am also able to communi...
# 1    Jonas       NaN                                            English
# 2    Ronan       NaN               English and Spanish are good for me.
# 3    Dulce       NaN                                            spanish
# 4   Evelyn       NaN                                            Spanish
# 5    Rocco       NaN                                            English
# 6  Everett       NaN                                            Español
# 7  Patrick       NaN                                    English is okay
# 8     Beau       NaN                                   English Russians
# 9  Valerie       NaN                                             french
#
#                                      Interested_Grp Age  \
# 0                 Product Marketing,Product Growth   23
# 1  Product Marketing,Product Growth ,Product Design  23
# 2                                    Product Design  34
# 3                                    Product Design  38
# 4                                 Product Marketing  22
# 5               Product Growth ,Product Development  21
# 6                  Product Design,Product Marketing  34
# 7                Product Design,Product Development  25
# 8                                    Product Design  24
# 9                                    Product Design  33
#
#                       City    Country    Region                   Timezone  \
# 0       bordj bou arreridj    Algeria      MENA              Europe,Africa
# 1                  Algiers    Algeria      MENA              Africa,Europe
# 2  Buenos Aires, Argentina  Argentina  Americas                   Americas
# 3                  Mendoza  Argentina  Americas                   Americas
# 4                    Tigre  Argentina  Americas          Any/No preference
# 5             Buenos Aires  Argentina  Americas                   Americas
# 6                    Junín  Argentina  Americas  Americas,Europe,Australia
# 7                  Yerevan    Armenia    Europe                Asia,Europe
# 8                  Yerevan    Armenia    Europe                     Europe
# 9                   Vienna   Autriche    Europe                     Europe
#
#                           Occupation  ... Product_Design Prodcut_Developement  \
# 0  Recently Graduated and Unemployed  ...            NaN                  NaN
# 1  Recently Graduated and Unemployed  ...              3                  NaN
# 2                           Employed  ...              4                  NaN
# 3                           Employed  ...              3                  NaN
# 4  Recently Graduated and Unemployed  ...            NaN                  NaN
# 5                 University Student  ...              3                    4
# 6                           Employed  ...              1                  NaN
# 7               Currently Unemployed  ...              3                    1
# 8  Recently Graduated and Unemployed  ...              5                  NaN
# 9               Currently Unemployed  ...              2                  NaN
#
#   Growth_Marketing Leading_Groups                     Internship_News  \
# 0                4            NaN                            linkedin
# 1                4              4                            Linkedin
# 2              NaN              5          A friend told me about it.
# 3              NaN              4                            Linkedin
# 4              NaN              4                            Linkedin
# 5                3            NaN                            LinkedIn
# 6              NaN            NaN                            Linkedin
# 7              NaN              5                         on LinkedIn
# 8              NaN              4                            LinkedIn
# 9              NaN              2  Friend of mine give me the website
#
#                             Cohort_Product_Marketing  \
# 0    Starting on 15th August,Starting on 22nd August
# 1  Starting on 12th September,Starting on 15th Au...
# 2                                                NaN
# 3                                                NaN
# 4    Starting on 22nd August,Starting on 15th August
# 5                                                NaN
# 6                      I would prefer a later cohort
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                Cohort_Product_Design  \
# 0                                                NaN
# 1    Starting on 3rd October,Starting on 22nd August
# 2                            Starting on 22nd August
# 3                            Starting on 22nd August
# 4                                                NaN
# 5                                                NaN
# 6                            Starting on 3rd October
# 7  Starting on 22nd August,Starting on 5th September
# 8                            Starting on 22nd August
# 9                            Starting on 22nd August
#
#   Cohort_Product_Development          Cohort_Product_Growth Hours_Per_Week
# 0                        NaN      Starting on 5th September    20-25 hours
# 1                        NaN        Starting on 3rd October    10-15 hours
# 2                        NaN                            NaN    15-20 hours
# 3                        NaN                            NaN    20-25 hours
# 4                        NaN                            NaN    20-25 hours
# 5    Starting on 3rd October  I would prefer a later cohort    10-15 hours
# 6                        NaN                            NaN    10-15 hours
# 7  Starting on 5th September                            NaN    10-15 hours
# 8                        NaN                            NaN    20-25 hours
# 9                        NaN                            NaN    10-15 hours
#
# [10 rows x 27 columns]

# %%
df.to_csv("Dataset.csv",index=False)

# %%
# The values in the column used to be objects which are now converted to float.
df["Digital_Marketing"] = pd.to_numeric(df["Digital_Marketing"], downcast="integer")

# %%
# finding mean of column
mean_df = (df['Digital_Marketing'].mean())
# replacing nan values with mean of column
df['Digital_Marketing'].fillna((mean_df) , inplace = True)
#changing type to integer
df['Digital_Marketing'] = df['Digital_Marketing'].astype(int)

# %%
df['Digital_Marketing']
# Out:
# 0       5
# 1       4
# 2       3
# 3       3
# 4       2
#        ..
# 1183    3
# 1184    3
# 1185    3
# 1186    4
# 1187    3
# Name: Digital_Marketing, Length: 1188, dtype: int32

# %%
df["Market_Research"] = pd.to_numeric(df["Market_Research"], downcast="float")
# filling NaN values with average of entire column
mean_df = (df['Market_Research'].mean())
# replacing nan values with mean of column
df['Market_Research'].fillna((mean_df) , inplace = True)
df['Market_Research'] = df['Market_Research'].astype(int)
df['Market_Research']
# Out:
# 0       3
# 1       4
# 2       3
# 3       2
# 4       2
#        ..
# 1183    1
# 1184    2
# 1185    5
# 1186    3
# 1187    2
# Name: Market_Research, Length: 1188, dtype: int32

# %%
# df['Digital_Illustration']
df["Digital_Illustration"] = pd.to_numeric(df["Digital_Illustration"], downcast="float")
# finding mean of column
mean_df = (df['Digital_Illustration'].mean())
# replacing nan values with mean of column
df['Digital_Illustration'].fillna((mean_df) , inplace = True)
df['Digital_Illustration'] = df['Digital_Illustration'].astype(int)
df['Digital_Illustration']
# Out:
# 0       1
# 1       2
# 2       3
# 3       3
# 4       2
#        ..
# 1183    2
# 1184    2
# 1185    3
# 1186    4
# 1187    2
# Name: Digital_Illustration, Length: 1188, dtype: int32

# %%
# df['Product_Design']
df["Product_Design"] = pd.to_numeric(df["Product_Design"], downcast="float")
# finding mean of column
mean_df = (df['Product_Design'].mean())
# replacing nan values with mean of column
df['Product_Design'].fillna((mean_df) , inplace = True)
df['Product_Design'] = df['Product_Design'].astype(int)
df['Product_Design']
# Out:
# 0       2
# 1       3
# 2       4
# 3       3
# 4       2
#        ..
# 1183    1
# 1184    1
# 1185    5
# 1186    3
# 1187    2
# Name: Product_Design, Length: 1188, dtype: int32

# %%
# df['Growth_Marketing']
df["Growth_Marketing"] = pd.to_numeric(df["Growth_Marketing"], downcast="float")
# finding mean
mean_df = (df['Growth_Marketing'].mean())
# replacing nan values with mean of column
df['Growth_Marketing'].fillna((mean_df) , inplace = True)
df['Growth_Marketing'] = df['Growth_Marketing'].astype(int)
df['Growth_Marketing']
# Out:
# 0       4
# 1       4
# 2       2
# 3       2
# 4       2
#        ..
# 1183    2
# 1184    2
# 1185    2
# 1186    1
# 1187    2
# Name: Growth_Marketing, Length: 1188, dtype: int32

# %%
# df['Leading_Groups']
df["Leading_Groups"] = pd.to_numeric(df["Leading_Groups"], downcast="float")
# finding mean of column
mean_df = (df['Leading_Groups'].mean())
# replacing nan values with mean of column 
df['Leading_Groups'].fillna((mean_df) , inplace = True)
df['Leading_Groups'] = df['Leading_Groups'].astype(int)
df['Leading_Groups']
# Out:
# 0       3
# 1       4
# 2       5
# 3       4
# 4       4
#        ..
# 1183    3
# 1184    3
# 1185    4
# 1186    3
# 1187    3
# Name: Leading_Groups, Length: 1188, dtype: int32

# %%
df[['Digital_Marketing' , 'Market_Research' , 'Digital_Illustration' , 'Product_Design' , 'Growth_Marketing' , 'Leading_Groups']].isnull().sum()
# Out:
# Digital_Marketing       0
# Market_Research         0
# Digital_Illustration    0
# Product_Design          0
# Growth_Marketing        0
# Leading_Groups          0
# dtype: int64
