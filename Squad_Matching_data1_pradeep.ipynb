# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('/content/sample_data/Dataset_Devesh(2).csv',parse_dates = True,encoding='latin-1')
df.head(20)
# Out:
#         Name  Squad_Num                                      Prefered_Lang  \
# 0    Grayson        NaN  i prefer english but i am also able to communi...
# 1      Jonas        NaN                                            English
# 2      Ronan        NaN               English and Spanish are good for me.
# 3      Dulce        NaN                                            spanish
# 4     Evelyn        NaN                                            Spanish
# 5      Rocco        NaN                                            English
# 6    Everett        NaN                                           EspaÃ±ol
# 7    Patrick        NaN                                    English is okay
# 8       Beau        NaN                                   English Russians
# 9    Valerie        NaN                                             french
# 10     Noemi        NaN                                            English
# 11     Rosie        NaN             English (I speak Azerbaijani, Russian)
# 12  Khaleesi        NaN                                                 No
# 13      Arya        NaN                                            English
# 14    Taylor        NaN                                            English
# 15    Oliver        NaN                            English, Hindi, Bangla
# 16   Enrique        NaN                                            English
# 17   Ibrahim        NaN                                            English
# 18    Jaylen        NaN                                             Bangla
# 19   Paisley        NaN                                                 no
#
#                                       Interested_Grp   Age  \
# 0                  Product Marketing,Product Growth   23.0
# 1   Product Marketing,Product Growth ,Product Design  23.0
# 2                                     Product Design  34.0
# 3                                     Product Design  38.0
# 4                                  Product Marketing  22.0
# 5                Product Growth ,Product Development  21.0
# 6                   Product Design,Product Marketing  34.0
# 7                 Product Design,Product Development  25.0
# 8                                     Product Design  24.0
# 9                                     Product Design  33.0
# 10                                    Product Design  19.0
# 11                                    Product Design  33.0
# 12                               Product Development  24.0
# 13                                    Product Design  19.0
# 14                                 Product Marketing  36.0
# 15                Product Design,Product Development  24.0
# 16                                 Product Marketing  21.0
# 17                               Product Development  23.0
# 18                               Product Development  23.0
# 19                 Product Marketing,Product Growth   24.0
#
#                                  City     Country    Region  \
# 0                  bordj bou arreridj     Algeria      MENA
# 1                             Algiers     Algeria      MENA
# 2             Buenos Aires, Argentina   Argentina  Americas
# 3                             Mendoza   Argentina  Americas
# 4                               Tigre   Argentina  Americas
# 5                        Buenos Aires   Argentina  Americas
# 6                              JunÃ­n   Argentina  Americas
# 7                             Yerevan     Armenia    Europe
# 8                             Yerevan     Armenia    Europe
# 9                              Vienna    Autriche    Europe
# 10                               Baku  Azerbaijan    Europe
# 11                               Baku  Azerbaijan    Europe
# 12                            Cumilla  Bangladesh      APAC
# 13                              Dhaka  Bangladesh      APAC
# 14                             Sylhet  Bangladesh      APAC
# 15                              Dhaka  Bangladesh      APAC
# 16  Dhaka, Dhaka Division, Bangladesh  Bangladesh      APAC
# 17                              Dhaka  Bangladesh      APAC
# 18                              Dhaka  Bangladesh      APAC
# 19                             sylhet  Bangladesh      APAC
#
#                      Timezone                         Occupation  ...  \
# 0               Europe,Africa  Recently Graduated and Unemployed  ...
# 1               Africa,Europe  Recently Graduated and Unemployed  ...
# 2                    Americas                           Employed  ...
# 3                    Americas                           Employed  ...
# 4           Any/No preference  Recently Graduated and Unemployed  ...
# 5                    Americas                 University Student  ...
# 6   Americas,Europe,Australia                           Employed  ...
# 7                 Asia,Europe               Currently Unemployed  ...
# 8                      Europe  Recently Graduated and Unemployed  ...
# 9                      Europe               Currently Unemployed  ...
# 10                       Asia                 University Student  ...
# 11         Europe,Africa,Asia               Currently Unemployed  ...
# 12                       Asia               Currently Unemployed  ...
# 13                       Asia                 University Student  ...
# 14                       Asia               Currently Unemployed  ...
# 15                       Asia                           Employed  ...
# 16                       Asia                 University Student  ...
# 17              Asia,Americas                 University Student  ...
# 18                       Asia                 University Student  ...
# 19          Any/No preference  Recently Graduated and Unemployed  ...
#
#    Product_Design Prodcut_Developement Growth_Marketing  Leading_Groups  \
# 0             NaN                  NaN              4.0             NaN
# 1             3.0                  NaN              4.0             4.0
# 2             4.0                  NaN              NaN             5.0
# 3             3.0                  NaN              NaN             4.0
# 4             NaN                  NaN              NaN             4.0
# 5             3.0                  4.0              3.0             NaN
# 6             1.0                  NaN              NaN             NaN
# 7             3.0                  1.0              NaN             5.0
# 8             5.0                  NaN              NaN             4.0
# 9             2.0                  NaN              NaN             2.0
# 10            4.0                  NaN              NaN             3.0
# 11            1.0                  NaN              NaN             NaN
# 12            5.0                  3.0              NaN             4.0
# 13            5.0                  NaN              NaN             4.0
# 14            NaN                  NaN              NaN             1.0
# 15            4.0                  1.0              NaN             4.0
# 16            NaN                  NaN              NaN             3.0
# 17            3.0                  4.0              NaN             5.0
# 18            1.0                  3.0              NaN             3.0
# 19            NaN                  NaN              4.0             4.0
#
#                                      Internship_News  \
# 0                                           linkedin
# 1                                           Linkedin
# 2                         A friend told me about it.
# 3                                           Linkedin
# 4                                           Linkedin
# 5                                           LinkedIn
# 6                                           Linkedin
# 7                                        on LinkedIn
# 8                                           LinkedIn
# 9                 Friend of mine give me the website
# 10                                     From linkedin
# 11                                          LinkedIn
# 12                                          LinkedIn
# 13  I learned about this internship through LinkedIn
# 14                               For get a ideal job
# 15                                          LinkedIn
# 16                                            Indeed
# 17                                     From LinkedIN
# 18                                          Linkedin
# 19                                          Linkedin
#
#                              Cohort_Product_Marketing  \
# 0     Starting on 15th August,Starting on 22nd August
# 1   Starting on 12th September,Starting on 15th Au...
# 2                                                 NaN
# 3                                                 NaN
# 4     Starting on 22nd August,Starting on 15th August
# 5                                                 NaN
# 6                       I would prefer a later cohort
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                            Starting on 22nd August
# 15                                                NaN
# 16                            Starting on 15th August
# 17                                                NaN
# 18                                                NaN
# 19    Starting on 15th August,Starting on 22nd August
#
#                                 Cohort_Product_Design  \
# 0                                                 NaN
# 1     Starting on 3rd October,Starting on 22nd August
# 2                             Starting on 22nd August
# 3                             Starting on 22nd August
# 4                                                 NaN
# 5                                                 NaN
# 6                             Starting on 3rd October
# 7   Starting on 22nd August,Starting on 5th September
# 8                             Starting on 22nd August
# 9                             Starting on 22nd August
# 10                          Starting on 5th September
# 11                          Starting on 5th September
# 12                                                NaN
# 13                            Starting on 22nd August
# 14                                                NaN
# 15                            Starting on 22nd August
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#        Cohort_Product_Development          Cohort_Product_Growth  \
# 0                             NaN      Starting on 5th September
# 1                             NaN        Starting on 3rd October
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5         Starting on 3rd October  I would prefer a later cohort
# 6                             NaN                            NaN
# 7       Starting on 5th September                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
# 10                            NaN                            NaN
# 11                            NaN                            NaN
# 12      Starting on 5th September                            NaN
# 13                            NaN                            NaN
# 14                            NaN                            NaN
# 15  I would prefer a later cohort                            NaN
# 16                            NaN                            NaN
# 17      Starting on 5th September                            NaN
# 18  I would prefer a later cohort                            NaN
# 19                            NaN      Starting on 5th September
#
#     Hours_Per_Week
# 0      20-25 hours
# 1      10-15 hours
# 2      15-20 hours
# 3      20-25 hours
# 4      20-25 hours
# 5      10-15 hours
# 6      10-15 hours
# 7      10-15 hours
# 8      20-25 hours
# 9      10-15 hours
# 10     15-20 hours
# 11     20-25 hours
# 12     15-20 hours
# 13     10-15 hours
# 14     10-15 hours
# 15     10-15 hours
# 16     20-25 hours
# 17     15-20 hours
# 18     15-20 hours
# 19     15-20 hours
#
# [20 rows x 27 columns]

# %%
#after Changing the null values form the original data set in Interested_Grp and Timezone these are the null values present
df.isnull().sum()
# Out:
# Name                             0
# Squad_Num                     1188
# Prefered_Lang                   19
# Interested_Grp                   0
# Age                              0
# City                             0
# Country                          0
# Region                           4
# Timezone                         0
# Occupation                       1
# Degree                           4
# Prev_Took_Courses                1
# Intern_Experience                1
# Product_Management               1
# Digital_Marketing              709
# Market_Research                220
# Digital_Illustration           303
# Product_Design                 265
# Prodcut_Developement           661
# Growth_Marketing               888
# Leading_Groups                 689
# Internship_News                  0
# Cohort_Product_Marketing       716
# Cohort_Product_Design          587
# Cohort_Product_Development     662
# Cohort_Product_Growth          889
# Hours_Per_Week                   0
# dtype: int64

# %%
#splliting the data using delimeter and extacting(storing) the first string in Interested_Grp

df['Interested_Grp']=df['Interested_Grp'].str.split(',').str[0]

# %%
df['Interested_Grp']
# Out:
# 0         Product Marketing
# 1         Product Marketing
# 2            Product Design
# 3            Product Design
# 4         Product Marketing
#                ...
# 1183    Product Development
# 1184    Product Development
# 1185         Product Design
# 1186      Product Marketing
# 1187    Product Development
# Name: Interested_Grp, Length: 1188, dtype: object

# %% [markdown]
# # DATA CLEANING FOR REGION & TIMEZONE

# %%
#collecting Region data contain null values
#df2 = Region data contain null values
df1=pd.isnull(df["Region"])
df2=df[df1]
df2
# Out:
#         Name  Squad_Num     Prefered_Lang       Interested_Grp   Age  \
# 139  Reyansh        NaN  English , Arabic  Product Development  22.0
# 220     Lola        NaN           English       Product Design  19.0
# 519    Gavin        NaN           English  Product Development  18.0
# 798  Giselle        NaN           English  Product Development  27.0
#
#             City       Country Region  \
# 139        Cairo         Egypt    NaN
# 220         Pune         India    NaN
# 519        Lagos       Nigeria    NaN
# 798  East London  South Africa    NaN
#
#                                            Timezone          Occupation  ...  \
# 139        Africa,Any/No preference,Europe,Americas  University Student  ...
# 220  Asia,Europe,Australia,Africa,Any/No preference  University Student  ...
# 519                                          Africa  University Student  ...
# 798                                   Africa,Europe  University Student  ...
#
#     Product_Design Prodcut_Developement Growth_Marketing  Leading_Groups  \
# 139            1.0                  4.0              NaN             NaN
# 220            3.0                  3.0              4.0             NaN
# 519            1.0                  3.0              NaN             NaN
# 798            1.0                  1.0              NaN             NaN
#
#                                        Internship_News  \
# 139                                    College friends
# 220                                           LinkedIn
# 519  I heard about this internship fron a colleague...
# 798                                           LinkedIn
#
#      Cohort_Product_Marketing      Cohort_Product_Design  \
# 139                       NaN                        NaN
# 220                       NaN  Starting on 5th September
# 519                       NaN                        NaN
# 798                       NaN                        NaN
#
#      Cohort_Product_Development      Cohort_Product_Growth  Hours_Per_Week
# 139     Starting on 3rd October                        NaN     20-25 hours
# 220   Starting on 5th September  Starting on 5th September     15-20 hours
# 519   Starting on 5th September                        NaN     15-20 hours
# 798   Starting on 5th September                        NaN     20-25 hours
#
# [4 rows x 27 columns]

# %%
#printing  timezone data which are in the same row of empty region
df2['Timezone']
# Out:
# 139          Africa,Any/No preference,Europe,Americas
# 220    Asia,Europe,Australia,Africa,Any/No preference
# 519                                            Africa
# 798                                     Africa,Europe
# Name: Timezone, dtype: object

# %%
#splliting the data using delimeter and extacting(storing) the first string
df2['Timezone']= df2['Timezone'].str.split(',').str[0]
df2['Timezone']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 139    Africa
# 220      Asia
# 519    Africa
# 798    Africa
# Name: Timezone, dtype: object

# %%
#Based on the Time zone replacing all the null values in the Region
df2['Region']=df2["Timezone"]
#df2['Region'] = df2['Region'].replace(['Africa','Asia'],['MENA','APAC'])

df2['Region']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 139    Africa
# 220      Asia
# 519    Africa
# 798    Africa
# Name: Region, dtype: object

# %%
# Regions and Timezones are replaced properly

df2
# Out:
#         Name  Squad_Num     Prefered_Lang       Interested_Grp   Age  \
# 139  Reyansh        NaN  English , Arabic  Product Development  22.0
# 220     Lola        NaN           English       Product Design  19.0
# 519    Gavin        NaN           English  Product Development  18.0
# 798  Giselle        NaN           English  Product Development  27.0
#
#             City       Country  Region Timezone          Occupation  ...  \
# 139        Cairo         Egypt  Africa   Africa  University Student  ...
# 220         Pune         India    Asia     Asia  University Student  ...
# 519        Lagos       Nigeria  Africa   Africa  University Student  ...
# 798  East London  South Africa  Africa   Africa  University Student  ...
#
#     Product_Design Prodcut_Developement Growth_Marketing  Leading_Groups  \
# 139            1.0                  4.0              NaN             NaN
# 220            3.0                  3.0              4.0             NaN
# 519            1.0                  3.0              NaN             NaN
# 798            1.0                  1.0              NaN             NaN
#
#                                        Internship_News  \
# 139                                    College friends
# 220                                           LinkedIn
# 519  I heard about this internship fron a colleague...
# 798                                           LinkedIn
#
#      Cohort_Product_Marketing      Cohort_Product_Design  \
# 139                       NaN                        NaN
# 220                       NaN  Starting on 5th September
# 519                       NaN                        NaN
# 798                       NaN                        NaN
#
#      Cohort_Product_Development      Cohort_Product_Growth  Hours_Per_Week
# 139     Starting on 3rd October                        NaN     20-25 hours
# 220   Starting on 5th September  Starting on 5th September     15-20 hours
# 519   Starting on 5th September                        NaN     15-20 hours
# 798   Starting on 5th September                        NaN     20-25 hours
#
# [4 rows x 27 columns]

# %%
df['Timezone']=df["Region"]
#df['Time Zone']
df['Timezone'] = df['Timezone'].replace(['APAC','MENA'],['Asia','Africa'])
df['Timezone']
# Out:
# 0         Africa
# 1         Africa
# 2       Americas
# 3       Americas
# 4       Americas
#           ...
# 1183    Americas
# 1184    Americas
# 1185    Americas
# 1186        Asia
# 1187        Asia
# Name: Timezone, Length: 1188, dtype: object

# %%
df
# Out:
#            Name  Squad_Num                                      Prefered_Lang  \
# 0       Grayson        NaN  i prefer english but i am also able to communi...
# 1         Jonas        NaN                                            English
# 2         Ronan        NaN               English and Spanish are good for me.
# 3         Dulce        NaN                                            spanish
# 4        Evelyn        NaN                                            Spanish
# ...         ...        ...                                                ...
# 1183  Johnathan        NaN                                            English
# 1184     Adriel        NaN  English is the language I am most comfortable ...
# 1185      Reyna        NaN                                            English
# 1186      Uriel        NaN                                            English
# 1187    Esteban        NaN                                         Vietnamese
#
#            Interested_Grp   Age                     City    Country    Region  \
# 0       Product Marketing  23.0       bordj bou arreridj    Algeria      MENA
# 1       Product Marketing  23.0                  Algiers    Algeria      MENA
# 2          Product Design  34.0  Buenos Aires, Argentina  Argentina  Americas
# 3          Product Design  38.0                  Mendoza  Argentina  Americas
# 4       Product Marketing  22.0                    Tigre  Argentina  Americas
# ...                   ...   ...                      ...        ...       ...
# 1183  Product Development  22.0   Las Cruces, New Mexico        USA  Americas
# 1184  Product Development  19.0                  seattle        USA  Americas
# 1185       Product Design  30.0                  Caracas  Venezuela  Americas
# 1186    Product Marketing  21.0                    Hanoi    Vietnam      APAC
# 1187  Product Development  23.0              Ho Chi Minh    Vietnam      APAC
#
#       Timezone                         Occupation  ... Product_Design  \
# 0       Africa  Recently Graduated and Unemployed  ...            NaN
# 1       Africa  Recently Graduated and Unemployed  ...            3.0
# 2     Americas                           Employed  ...            4.0
# 3     Americas                           Employed  ...            3.0
# 4     Americas  Recently Graduated and Unemployed  ...            NaN
# ...        ...                                ...  ...            ...
# 1183  Americas  Recently Graduated and Unemployed  ...            1.0
# 1184  Americas                 University Student  ...            1.0
# 1185  Americas                           Employed  ...            5.0
# 1186      Asia                 University Student  ...            3.0
# 1187      Asia                 University Student  ...            2.0
#
#      Prodcut_Developement Growth_Marketing  Leading_Groups  \
# 0                     NaN              4.0             NaN
# 1                     NaN              4.0             4.0
# 2                     NaN              NaN             5.0
# 3                     NaN              NaN             4.0
# 4                     NaN              NaN             4.0
# ...                   ...              ...             ...
# 1183                  4.0              2.0             NaN
# 1184                  3.0              NaN             NaN
# 1185                  NaN              NaN             4.0
# 1186                  NaN              1.0             3.0
# 1187                  4.0              NaN             NaN
#
#                  Internship_News  \
# 0                       linkedin
# 1                       Linkedin
# 2     A friend told me about it.
# 3                       Linkedin
# 4                       Linkedin
# ...                          ...
# 1183                    LinkedIn
# 1184       I saw it on linkedin.
# 1185                    LinkedIn
# 1186      I saw this on LinkedIn
# 1187                    Linkedln
#
#                                Cohort_Product_Marketing  \
# 0       Starting on 15th August,Starting on 22nd August
# 1     Starting on 12th September,Starting on 15th Au...
# 2                                                   NaN
# 3                                                   NaN
# 4       Starting on 22nd August,Starting on 15th August
# ...                                                 ...
# 1183                                                NaN
# 1184                                                NaN
# 1185                                                NaN
# 1186                            Starting on 15th August
# 1187                                                NaN
#
#                                   Cohort_Product_Design  \
# 0                                                   NaN
# 1       Starting on 3rd October,Starting on 22nd August
# 2                               Starting on 22nd August
# 3                               Starting on 22nd August
# 4                                                   NaN
# ...                                                 ...
# 1183                                                NaN
# 1184                                                NaN
# 1185  Starting on 5th September,Starting on 22nd August
# 1186                            Starting on 22nd August
# 1187                                                NaN
#
#       Cohort_Product_Development      Cohort_Product_Growth  Hours_Per_Week
# 0                            NaN  Starting on 5th September     20-25 hours
# 1                            NaN    Starting on 3rd October     10-15 hours
# 2                            NaN                        NaN     15-20 hours
# 3                            NaN                        NaN     20-25 hours
# 4                            NaN                        NaN     20-25 hours
# ...                          ...                        ...             ...
# 1183   Starting on 5th September  Starting on 5th September     20-25 hours
# 1184   Starting on 5th September                        NaN     15-20 hours
# 1185                         NaN                        NaN     10-15 hours
# 1186                         NaN  Starting on 5th September     15-20 hours
# 1187   Starting on 5th September                        NaN     10-15 hours
#
# [1188 rows x 27 columns]

# %%
# df2 values are storing in the main dataframe (df)
df.loc[df2.index, :] = df2[:]

# %%
df
# Out:
#            Name  Squad_Num                                      Prefered_Lang  \
# 0       Grayson        NaN  i prefer english but i am also able to communi...
# 1         Jonas        NaN                                            English
# 2         Ronan        NaN               English and Spanish are good for me.
# 3         Dulce        NaN                                            spanish
# 4        Evelyn        NaN                                            Spanish
# ...         ...        ...                                                ...
# 1183  Johnathan        NaN                                            English
# 1184     Adriel        NaN  English is the language I am most comfortable ...
# 1185      Reyna        NaN                                            English
# 1186      Uriel        NaN                                            English
# 1187    Esteban        NaN                                         Vietnamese
#
#            Interested_Grp   Age                     City    Country    Region  \
# 0       Product Marketing  23.0       bordj bou arreridj    Algeria      MENA
# 1       Product Marketing  23.0                  Algiers    Algeria      MENA
# 2          Product Design  34.0  Buenos Aires, Argentina  Argentina  Americas
# 3          Product Design  38.0                  Mendoza  Argentina  Americas
# 4       Product Marketing  22.0                    Tigre  Argentina  Americas
# ...                   ...   ...                      ...        ...       ...
# 1183  Product Development  22.0   Las Cruces, New Mexico        USA  Americas
# 1184  Product Development  19.0                  seattle        USA  Americas
# 1185       Product Design  30.0                  Caracas  Venezuela  Americas
# 1186    Product Marketing  21.0                    Hanoi    Vietnam      APAC
# 1187  Product Development  23.0              Ho Chi Minh    Vietnam      APAC
#
#       Timezone                         Occupation  ... Product_Design  \
# 0       Africa  Recently Graduated and Unemployed  ...            NaN
# 1       Africa  Recently Graduated and Unemployed  ...            3.0
# 2     Americas                           Employed  ...            4.0
# 3     Americas                           Employed  ...            3.0
# 4     Americas  Recently Graduated and Unemployed  ...            NaN
# ...        ...                                ...  ...            ...
# 1183  Americas  Recently Graduated and Unemployed  ...            1.0
# 1184  Americas                 University Student  ...            1.0
# 1185  Americas                           Employed  ...            5.0
# 1186      Asia                 University Student  ...            3.0
# 1187      Asia                 University Student  ...            2.0
#
#      Prodcut_Developement Growth_Marketing  Leading_Groups  \
# 0                     NaN              4.0             NaN
# 1                     NaN              4.0             4.0
# 2                     NaN              NaN             5.0
# 3                     NaN              NaN             4.0
# 4                     NaN              NaN             4.0
# ...                   ...              ...             ...
# 1183                  4.0              2.0             NaN
# 1184                  3.0              NaN             NaN
# 1185                  NaN              NaN             4.0
# 1186                  NaN              1.0             3.0
# 1187                  4.0              NaN             NaN
#
#                  Internship_News  \
# 0                       linkedin
# 1                       Linkedin
# 2     A friend told me about it.
# 3                       Linkedin
# 4                       Linkedin
# ...                          ...
# 1183                    LinkedIn
# 1184       I saw it on linkedin.
# 1185                    LinkedIn
# 1186      I saw this on LinkedIn
# 1187                    Linkedln
#
#                                Cohort_Product_Marketing  \
# 0       Starting on 15th August,Starting on 22nd August
# 1     Starting on 12th September,Starting on 15th Au...
# 2                                                   NaN
# 3                                                   NaN
# 4       Starting on 22nd August,Starting on 15th August
# ...                                                 ...
# 1183                                                NaN
# 1184                                                NaN
# 1185                                                NaN
# 1186                            Starting on 15th August
# 1187                                                NaN
#
#                                   Cohort_Product_Design  \
# 0                                                   NaN
# 1       Starting on 3rd October,Starting on 22nd August
# 2                               Starting on 22nd August
# 3                               Starting on 22nd August
# 4                                                   NaN
# ...                                                 ...
# 1183                                                NaN
# 1184                                                NaN
# 1185  Starting on 5th September,Starting on 22nd August
# 1186                            Starting on 22nd August
# 1187                                                NaN
#
#       Cohort_Product_Development      Cohort_Product_Growth  Hours_Per_Week
# 0                            NaN  Starting on 5th September     20-25 hours
# 1                            NaN    Starting on 3rd October     10-15 hours
# 2                            NaN                        NaN     15-20 hours
# 3                            NaN                        NaN     20-25 hours
# 4                            NaN                        NaN     20-25 hours
# ...                          ...                        ...             ...
# 1183   Starting on 5th September  Starting on 5th September     20-25 hours
# 1184   Starting on 5th September                        NaN     15-20 hours
# 1185                         NaN                        NaN     10-15 hours
# 1186                         NaN  Starting on 5th September     15-20 hours
# 1187   Starting on 5th September                        NaN     10-15 hours
#
# [1188 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# Name                             0
# Squad_Num                     1188
# Prefered_Lang                   19
# Interested_Grp                   0
# Age                              0
# City                             0
# Country                          0
# Region                           0
# Timezone                         0
# Occupation                       1
# Degree                           4
# Prev_Took_Courses                1
# Intern_Experience                1
# Product_Management               1
# Digital_Marketing              709
# Market_Research                220
# Digital_Illustration           303
# Product_Design                 265
# Prodcut_Developement           661
# Growth_Marketing               888
# Leading_Groups                 689
# Internship_News                  0
# Cohort_Product_Marketing       716
# Cohort_Product_Design          587
# Cohort_Product_Development     662
# Cohort_Product_Growth          889
# Hours_Per_Week                   0
# dtype: int64

# %% [markdown]
# # Data Cleaning for Prefrred language

# %%
#using Regex pattern we are storing  the first prefrred language of the person
df['Prefered_Lang']=df['Prefered_Lang'].replace(to_replace='.*[fF,]r.*', value= 'French', regex= True) 
df['Prefered_Lang']=df['Prefered_Lang'].replace(to_replace='.*[Ee,]n.*', value= 'English', regex= True)  
df['Prefered_Lang']=df['Prefered_Lang'].replace(to_replace='.*[Aa,]r.*', value= 'Arabic', regex= True)  
df['Prefered_Lang']=df['Prefered_Lang'].replace(to_replace='.*[eE,]N.*', value= 'English', regex= True)  
df['Prefered_Lang']=df['Prefered_Lang'].replace(to_replace='.*[Bb,]a.*', value= 'Bahasa', regex= True)  
df['Prefered_Lang']=df['Prefered_Lang'].replace(to_replace='.*[Uu,]r.*', value= 'Urdu', regex= True)
df['Prefered_Lang']=df['Prefered_Lang'].replace(to_replace='.*[Uu,]k.*', value= 'Ukranian', regex= True)  
df['Prefered_Lang']=df['Prefered_Lang'].replace(to_replace='.*[Tt,]a.*', value= 'Tamil', regex= True)  
df['Prefered_Lang']=df['Prefered_Lang'].replace(to_replace='.*[Ss,]p.*', value= 'Spanish', regex= True)  
df['Prefered_Lang']=df['Prefered_Lang'].replace(to_replace='.*[Hh,]i.*', value= 'Hindi', regex= True)  
df['Prefered_Lang']=df['Prefered_Lang'].replace(to_replace='.*[pP,]u.*', value= 'Punjabi', regex= True)

# %%
df
# Out:
#            Name  Squad_Num Prefered_Lang  \
# 0       Grayson        NaN       English
# 1         Jonas        NaN       English
# 2         Ronan        NaN       English
# 3         Dulce        NaN       Spanish
# 4        Evelyn        NaN       Spanish
# ...         ...        ...           ...
# 1183  Johnathan        NaN       English
# 1184     Adriel        NaN       English
# 1185      Reyna        NaN       English
# 1186      Uriel        NaN       English
# 1187    Esteban        NaN    Vietnamese
#
#                                         Interested_Grp   Age  \
# 0                    Product Marketing,Product Growth   23.0
# 1     Product Marketing,Product Growth ,Product Design  23.0
# 2                                       Product Design  34.0
# 3                                       Product Design  38.0
# 4                                    Product Marketing  22.0
# ...                                                ...   ...
# 1183               Product Development,Product Growth   22.0
# 1184                               Product Development  19.0
# 1185                                    Product Design  30.0
# 1186  Product Marketing,Product Design,Product Growth   21.0
# 1187                               Product Development  23.0
#
#                          City    Country    Region  \
# 0          bordj bou arreridj    Algeria      MENA
# 1                     Algiers    Algeria      MENA
# 2     Buenos Aires, Argentina  Argentina  Americas
# 3                     Mendoza  Argentina  Americas
# 4                       Tigre  Argentina  Americas
# ...                       ...        ...       ...
# 1183   Las Cruces, New Mexico        USA  Americas
# 1184                  seattle        USA  Americas
# 1185                  Caracas  Venezuela  Americas
# 1186                    Hanoi    Vietnam      APAC
# 1187              Ho Chi Minh    Vietnam      APAC
#
#                         Timezone                         Occupation  ...  \
# 0                  Europe,Africa  Recently Graduated and Unemployed  ...
# 1                  Africa,Europe  Recently Graduated and Unemployed  ...
# 2                       Americas                           Employed  ...
# 3                       Americas                           Employed  ...
# 4              Any/No preference  Recently Graduated and Unemployed  ...
# ...                          ...                                ...  ...
# 1183  Americas,Any/No preference  Recently Graduated and Unemployed  ...
# 1184                    Americas                 University Student  ...
# 1185                    Americas                           Employed  ...
# 1186                        Asia                 University Student  ...
# 1187                        Asia                 University Student  ...
#
#      Product_Design Prodcut_Developement Growth_Marketing  Leading_Groups  \
# 0               NaN                  NaN              4.0             NaN
# 1               3.0                  NaN              4.0             4.0
# 2               4.0                  NaN              NaN             5.0
# 3               3.0                  NaN              NaN             4.0
# 4               NaN                  NaN              NaN             4.0
# ...             ...                  ...              ...             ...
# 1183            1.0                  4.0              2.0             NaN
# 1184            1.0                  3.0              NaN             NaN
# 1185            5.0                  NaN              NaN             4.0
# 1186            3.0                  NaN              1.0             3.0
# 1187            2.0                  4.0              NaN             NaN
#
#                  Internship_News  \
# 0                       linkedin
# 1                       Linkedin
# 2     A friend told me about it.
# 3                       Linkedin
# 4                       Linkedin
# ...                          ...
# 1183                    LinkedIn
# 1184       I saw it on linkedin.
# 1185                    LinkedIn
# 1186      I saw this on LinkedIn
# 1187                    Linkedln
#
#                                Cohort_Product_Marketing  \
# 0       Starting on 15th August,Starting on 22nd August
# 1     Starting on 12th September,Starting on 15th Au...
# 2                                                   NaN
# 3                                                   NaN
# 4       Starting on 22nd August,Starting on 15th August
# ...                                                 ...
# 1183                                                NaN
# 1184                                                NaN
# 1185                                                NaN
# 1186                            Starting on 15th August
# 1187                                                NaN
#
#                                   Cohort_Product_Design  \
# 0                                                   NaN
# 1       Starting on 3rd October,Starting on 22nd August
# 2                               Starting on 22nd August
# 3                               Starting on 22nd August
# 4                                                   NaN
# ...                                                 ...
# 1183                                                NaN
# 1184                                                NaN
# 1185  Starting on 5th September,Starting on 22nd August
# 1186                            Starting on 22nd August
# 1187                                                NaN
#
#       Cohort_Product_Development      Cohort_Product_Growth  Hours_Per_Week
# 0                            NaN  Starting on 5th September     20-25 hours
# 1                            NaN    Starting on 3rd October     10-15 hours
# 2                            NaN                        NaN     15-20 hours
# 3                            NaN                        NaN     20-25 hours
# 4                            NaN                        NaN     20-25 hours
# ...                          ...                        ...             ...
# 1183   Starting on 5th September  Starting on 5th September     20-25 hours
# 1184   Starting on 5th September                        NaN     15-20 hours
# 1185                         NaN                        NaN     10-15 hours
# 1186                         NaN  Starting on 5th September     15-20 hours
# 1187   Starting on 5th September                        NaN     10-15 hours
#
# [1188 rows x 27 columns]

# %%
df['Prefered_Lang'] = df['Prefered_Lang'].mask(df['Prefered_Lang'] == 'null').ffill()

# %%
df.isnull().sum()
# Out:
# Name                             0
# Squad_Num                     1188
# Prefered_Lang                    0
# Interested_Grp                   0
# Age                              0
# City                             0
# Country                          0
# Region                           4
# Timezone                         0
# Occupation                       1
# Degree                           4
# Prev_Took_Courses                1
# Intern_Experience                1
# Product_Management               1
# Digital_Marketing              709
# Market_Research                220
# Digital_Illustration           303
# Product_Design                 265
# Prodcut_Developement           661
# Growth_Marketing               888
# Leading_Groups                 689
# Internship_News                  0
# Cohort_Product_Marketing       716
# Cohort_Product_Design          587
# Cohort_Product_Development     662
# Cohort_Product_Growth          889
# Hours_Per_Week                   0
# dtype: int64

# %% [markdown]
# # LABEL ENCODING

# %%
labelencoder = LabelEncoder()

df['Prefered_Lang'] = labelencoder.fit_transform(df['Prefered_Lang'])
df['Interested_Grp'] = labelencoder.fit_transform(df['Interested_Grp'])
df['Country'] = labelencoder.fit_transform(df['Country'])
df['Region'] = labelencoder.fit_transform(df['Region'])
df['Timezone'] = labelencoder.fit_transform(df['Timezone'])

# %%
df.to_csv('final2 data.csv')

# %%
df
# Out:
#            Name  Squad_Num  Prefered_Lang  Interested_Grp   Age  \
# 0       Grayson        NaN              4              46  23.0
# 1         Jonas        NaN              4              47  23.0
# 2         Ronan        NaN              4               0  34.0
# 3         Dulce        NaN             27               0  38.0
# 4        Evelyn        NaN             27              35  22.0
# ...         ...        ...            ...             ...   ...
# 1183  Johnathan        NaN              4              17  22.0
# 1184     Adriel        NaN              4              11  19.0
# 1185      Reyna        NaN              4               0  30.0
# 1186      Uriel        NaN              4              39  21.0
# 1187    Esteban        NaN             32              11  23.0
#
#                          City  Country  Region  Timezone  \
# 0          bordj bou arreridj        0       4        55
# 1                     Algiers        0       4        10
# 2     Buenos Aires, Argentina        1       2        14
# 3                     Mendoza        1       2        14
# 4                       Tigre        1       2        29
# ...                       ...      ...     ...       ...
# 1183   Las Cruces, New Mexico       56       2        16
# 1184                  seattle       56       2        14
# 1185                  Caracas       59       2        14
# 1186                    Hanoi       60       0        38
# 1187              Ho Chi Minh       60       0        38
#
#                              Occupation  ... Product_Design  \
# 0     Recently Graduated and Unemployed  ...            NaN
# 1     Recently Graduated and Unemployed  ...            3.0
# 2                              Employed  ...            4.0
# 3                              Employed  ...            3.0
# 4     Recently Graduated and Unemployed  ...            NaN
# ...                                 ...  ...            ...
# 1183  Recently Graduated and Unemployed  ...            1.0
# 1184                 University Student  ...            1.0
# 1185                           Employed  ...            5.0
# 1186                 University Student  ...            3.0
# 1187                 University Student  ...            2.0
#
#      Prodcut_Developement Growth_Marketing  Leading_Groups  \
# 0                     NaN              4.0             NaN
# 1                     NaN              4.0             4.0
# 2                     NaN              NaN             5.0
# 3                     NaN              NaN             4.0
# 4                     NaN              NaN             4.0
# ...                   ...              ...             ...
# 1183                  4.0              2.0             NaN
# 1184                  3.0              NaN             NaN
# 1185                  NaN              NaN             4.0
# 1186                  NaN              1.0             3.0
# 1187                  4.0              NaN             NaN
#
#                  Internship_News  \
# 0                       linkedin
# 1                       Linkedin
# 2     A friend told me about it.
# 3                       Linkedin
# 4                       Linkedin
# ...                          ...
# 1183                    LinkedIn
# 1184       I saw it on linkedin.
# 1185                    LinkedIn
# 1186      I saw this on LinkedIn
# 1187                    Linkedln
#
#                                Cohort_Product_Marketing  \
# 0       Starting on 15th August,Starting on 22nd August
# 1     Starting on 12th September,Starting on 15th Au...
# 2                                                   NaN
# 3                                                   NaN
# 4       Starting on 22nd August,Starting on 15th August
# ...                                                 ...
# 1183                                                NaN
# 1184                                                NaN
# 1185                                                NaN
# 1186                            Starting on 15th August
# 1187                                                NaN
#
#                                   Cohort_Product_Design  \
# 0                                                   NaN
# 1       Starting on 3rd October,Starting on 22nd August
# 2                               Starting on 22nd August
# 3                               Starting on 22nd August
# 4                                                   NaN
# ...                                                 ...
# 1183                                                NaN
# 1184                                                NaN
# 1185  Starting on 5th September,Starting on 22nd August
# 1186                            Starting on 22nd August
# 1187                                                NaN
#
#       Cohort_Product_Development      Cohort_Product_Growth  Hours_Per_Week
# 0                            NaN  Starting on 5th September     20-25 hours
# 1                            NaN    Starting on 3rd October     10-15 hours
# 2                            NaN                        NaN     15-20 hours
# 3                            NaN                        NaN     20-25 hours
# 4                            NaN                        NaN     20-25 hours
# ...                          ...                        ...             ...
# 1183   Starting on 5th September  Starting on 5th September     20-25 hours
# 1184   Starting on 5th September                        NaN     15-20 hours
# 1185                         NaN                        NaN     10-15 hours
# 1186                         NaN  Starting on 5th September     15-20 hours
# 1187   Starting on 5th September                        NaN     10-15 hours
#
# [1188 rows x 27 columns]
